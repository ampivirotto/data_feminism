# %%
import pandas as pd  ## for tables
import numpy as np  ## for arrays
import matplotlib.pyplot as plt ## for figures
import seaborn as sns ## for prettier figures

# %%
df = pd.read_csv('spotify.csv')  # read in spotify data
df
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0
#
# [366 rows x 6 columns]

# %%
## from example: https://matplotlib.org/stable/gallery/ticks/ticklabels_rotation.html
fig, ax = plt.subplots()

ax.plot(df['Date'], df['Shape of You'])

xticks = list(df['Date'])
xlabels = 
#ax.tick_params()

ax.set_xticks(df['Date'], df['Date'], rotation='vertical')
# Out:
# [<matplotlib.axis.XTick at 0x15de6f07230>,
#  <matplotlib.axis.XTick at 0x15de6f071d0>,
#  <matplotlib.axis.XTick at 0x15de6de8cb0>,
#  <matplotlib.axis.XTick at 0x15de6ef7410>,
#  <matplotlib.axis.XTick at 0x15de6ef4140>,
#  <matplotlib.axis.XTick at 0x15de6ef52b0>,
#  <matplotlib.axis.XTick at 0x15de5e3e540>,
#  <matplotlib.axis.XTick at 0x15de6ed39b0>,
#  <matplotlib.axis.XTick at 0x15de6e64380>,
#  <matplotlib.axis.XTick at 0x15de6e4b680>,
#  <matplotlib.axis.XTick at 0x15de6e4b980>,
#  <matplotlib.axis.XTick at 0x15de6e7d5b0>,
#  <matplotlib.axis.XTick at 0x15de62d48c0>,
#  <matplotlib.axis.XTick at 0x15de62d5220>,
#  <matplotlib.axis.XTick at 0x15de62d5b20>,
#  <matplotlib.axis.XTick at 0x15de62d6360>,
#  <matplotlib.axis.XTick at 0x15de6f07110>,
#  <matplotlib.axis.XTick at 0x15de62d6720>,
#  <matplotlib.axis.XTick at 0x15de62d7050>,
#  <matplotlib.axis.XTick at 0x15de62d7950>,
#  <matplotlib.axis.XTick at 0x15de62ec260>,
#  <matplotlib.axis.XTick at 0x15de62d7230>,
#  <matplotlib.axis.XTick at 0x15de62ec980>,
#  <matplotlib.axis.XTick at 0x15de62ed2b0>,
#  <matplotlib.axis.XTick at 0x15de62edc10>,
#  <matplotlib.axis.XTick at 0x15de62ee5d0>,
#  <matplotlib.axis.XTick at 0x15de6e49b20>,
#  <matplotlib.axis.XTick at 0x15de62ecb60>,
#  <matplotlib.axis.XTick at 0x15de62ef620>,
#  <matplotlib.axis.XTick at 0x15de62effb0>,
#  <matplotlib.axis.XTick at 0x15de63048f0>,
#  <matplotlib.axis.XTick at 0x15de63051f0>,
#  <matplotlib.axis.XTick at 0x15de62ef0b0>,
#  <matplotlib.axis.XTick at 0x15de6305820>,
#  <matplotlib.axis.XTick at 0x15de63061b0>,
#  <matplotlib.axis.XTick at 0x15de6306b10>,
#  <matplotlib.axis.XTick at 0x15de63073e0>,
#  <matplotlib.axis.XTick at 0x15de6306d20>,
#  <matplotlib.axis.XTick at 0x15de6307980>,
#  <matplotlib.axis.XTick at 0x15de6324320>,
#  <matplotlib.axis.XTick at 0x15de6324cb0>,
#  <matplotlib.axis.XTick at 0x15de63255b0>,
#  <matplotlib.axis.XTick at 0x15de6305c10>,
#  <matplotlib.axis.XTick at 0x15de6325ca0>,
#  <matplotlib.axis.XTick at 0x15de6326540>,
#  <matplotlib.axis.XTick at 0x15de6326e70>,
#  <matplotlib.axis.XTick at 0x15de63277a0>,
#  <matplotlib.axis.XTick at 0x15de6327d70>,
#  <matplotlib.axis.XTick at 0x15de6326030>,
#  <matplotlib.axis.XTick at 0x15de63347d0>,
#  <matplotlib.axis.XTick at 0x15de6335100>,
#  <matplotlib.axis.XTick at 0x15de6335940>,
#  <matplotlib.axis.XTick at 0x15de63362d0>,
#  <matplotlib.axis.XTick at 0x15de6335c40>,
#  <matplotlib.axis.XTick at 0x15de6336960>,
#  <matplotlib.axis.XTick at 0x15de6337320>,
#  <matplotlib.axis.XTick at 0x15de6337bf0>,
#  <matplotlib.axis.XTick at 0x15de634c5c0>,
#  <matplotlib.axis.XTick at 0x15de6336f00>,
#  <matplotlib.axis.XTick at 0x15de634cda0>,
#  <matplotlib.axis.XTick at 0x15de634d760>,
#  <matplotlib.axis.XTick at 0x15de634d850>,
#  <matplotlib.axis.XTick at 0x15de634e690>,
#  <matplotlib.axis.XTick at 0x15de634ee70>,
#  <matplotlib.axis.XTick at 0x15de634eb40>,
#  <matplotlib.axis.XTick at 0x15de634cfb0>,
#  <matplotlib.axis.XTick at 0x15de634f740>,
#  <matplotlib.axis.XTick at 0x15de634d0a0>,
#  <matplotlib.axis.XTick at 0x15de634f8c0>,
#  <matplotlib.axis.XTick at 0x15de634fec0>,
#  <matplotlib.axis.XTick at 0x15de634dc40>,
#  <matplotlib.axis.XTick at 0x15de636d1f0>,
#  <matplotlib.axis.XTick at 0x15de636c8f0>,
#  <matplotlib.axis.XTick at 0x15de636df70>,
#  <matplotlib.axis.XTick at 0x15de636e720>,
#  <matplotlib.axis.XTick at 0x15de634d070>,
#  <matplotlib.axis.XTick at 0x15de636cfe0>,
#  <matplotlib.axis.XTick at 0x15de636f0b0>,
#  <matplotlib.axis.XTick at 0x15de636f950>,
#  <matplotlib.axis.XTick at 0x15de6390290>,
#  <matplotlib.axis.XTick at 0x15de6390aa0>,
#  <matplotlib.axis.XTick at 0x15de636f500>,
#  <matplotlib.axis.XTick at 0x15de634f0e0>,
#  <matplotlib.axis.XTick at 0x15de636f6e0>,
#  <matplotlib.axis.XTick at 0x15de6390f50>,
#  <matplotlib.axis.XTick at 0x15de63915e0>,
#  <matplotlib.axis.XTick at 0x15de6391e50>,
#  <matplotlib.axis.XTick at 0x15de636dd60>,
#  <matplotlib.axis.XTick at 0x15de6390500>,
#  <matplotlib.axis.XTick at 0x15de6392810>,
#  <matplotlib.axis.XTick at 0x15de6392e40>,
#  <matplotlib.axis.XTick at 0x15de63936e0>,
#  <matplotlib.axis.XTick at 0x15de6325a90>,
#  <matplotlib.axis.XTick at 0x15de6392c00>,
#  <matplotlib.axis.XTick at 0x15de6393d40>,
#  <matplotlib.axis.XTick at 0x15de6fac830>,
#  <matplotlib.axis.XTick at 0x15de6facef0>,
#  <matplotlib.axis.XTick at 0x15de6fad640>,
#  <matplotlib.axis.XTick at 0x15de63911c0>,
#  <matplotlib.axis.XTick at 0x15de6faca40>,
#  <matplotlib.axis.XTick at 0x15de6fae030>,
#  <matplotlib.axis.XTick at 0x15de6fae720>,
#  <matplotlib.axis.XTick at 0x15de6faeed0>,
#  <matplotlib.axis.XTick at 0x15de6faf560>,
#  <matplotlib.axis.XTick at 0x15de6faecf0>,
#  <matplotlib.axis.XTick at 0x15de6fad1c0>,
#  <matplotlib.axis.XTick at 0x15de6faf1a0>,
#  <matplotlib.axis.XTick at 0x15de6fac050>,
#  <matplotlib.axis.XTick at 0x15de6fd0f50>,
#  <matplotlib.axis.XTick at 0x15de6fafe90>,
#  <matplotlib.axis.XTick at 0x15de6d9d220>,
#  <matplotlib.axis.XTick at 0x15de6fd1a90>,
#  <matplotlib.axis.XTick at 0x15de6fd21b0>,
#  <matplotlib.axis.XTick at 0x15de6fd2990>,
#  <matplotlib.axis.XTick at 0x15de6fd2f90>,
#  <matplotlib.axis.XTick at 0x15de6fd1bb0>,
#  <matplotlib.axis.XTick at 0x15de6fd1940>,
#  <matplotlib.axis.XTick at 0x15de6fd3b00>,
#  <matplotlib.axis.XTick at 0x15de6ff8410>,
#  <matplotlib.axis.XTick at 0x15de6ff88c0>,
#  <matplotlib.axis.XTick at 0x15de6ff90d0>,
#  <matplotlib.axis.XTick at 0x15de6fd36b0>,
#  <matplotlib.axis.XTick at 0x15de6ff8290>,
#  <matplotlib.axis.XTick at 0x15de6ff9c10>,
#  <matplotlib.axis.XTick at 0x15de6ffa270>,
#  <matplotlib.axis.XTick at 0x15de6ffab40>,
#  <matplotlib.axis.XTick at 0x15de6fd1820>,
#  <matplotlib.axis.XTick at 0x15de6ff9f70>,
#  <matplotlib.axis.XTick at 0x15de6ffb590>,
#  <matplotlib.axis.XTick at 0x15de6ffbc50>,
#  <matplotlib.axis.XTick at 0x15de70145f0>,
#  <matplotlib.axis.XTick at 0x15de7014dd0>,
#  <matplotlib.axis.XTick at 0x15de6ffb4a0>,
#  <matplotlib.axis.XTick at 0x15de70143e0>,
#  <matplotlib.axis.XTick at 0x15de7015910>,
#  <matplotlib.axis.XTick at 0x15de7015f10>,
#  <matplotlib.axis.XTick at 0x15de7016720>,
#  <matplotlib.axis.XTick at 0x15de7016e40>,
#  <matplotlib.axis.XTick at 0x15de7016ae0>,
#  <matplotlib.axis.XTick at 0x15de70148f0>,
#  <matplotlib.axis.XTick at 0x15de70176e0>,
#  <matplotlib.axis.XTick at 0x15de7017e60>,
#  <matplotlib.axis.XTick at 0x15de7038710>,
#  <matplotlib.axis.XTick at 0x15de7017bc0>,
#  <matplotlib.axis.XTick at 0x15de7015f40>,
#  <matplotlib.axis.XTick at 0x15de7039100>,
#  <matplotlib.axis.XTick at 0x15de70397f0>,
#  <matplotlib.axis.XTick at 0x15de7039f10>,
#  <matplotlib.axis.XTick at 0x15de703a750>,
#  <matplotlib.axis.XTick at 0x15de70171a0>,
#  <matplotlib.axis.XTick at 0x15de6fd1430>,
#  <matplotlib.axis.XTick at 0x15de7039760>,
#  <matplotlib.axis.XTick at 0x15de703ae40>,
#  <matplotlib.axis.XTick at 0x15de703b500>,
#  <matplotlib.axis.XTick at 0x15de703bd10>,
#  <matplotlib.axis.XTick at 0x15de703b260>,
#  <matplotlib.axis.XTick at 0x15de703bbf0>,
#  <matplotlib.axis.XTick at 0x15de705c830>,
#  <matplotlib.axis.XTick at 0x15de705ce00>,
#  <matplotlib.axis.XTick at 0x15de705d580>,
#  <matplotlib.axis.XTick at 0x15de705de20>,
#  <matplotlib.axis.XTick at 0x15de705d9d0>,
#  <matplotlib.axis.XTick at 0x15de705c410>,
#  <matplotlib.axis.XTick at 0x15de705e750>,
#  <matplotlib.axis.XTick at 0x15de705ee70>,
#  <matplotlib.axis.XTick at 0x15de705f5f0>,
#  <matplotlib.axis.XTick at 0x15de70385f0>,
#  <matplotlib.axis.XTick at 0x15de705eae0>,
#  <matplotlib.axis.XTick at 0x15de705f950>,
#  <matplotlib.axis.XTick at 0x15de7084770>,
#  <matplotlib.axis.XTick at 0x15de7084e60>,
#  <matplotlib.axis.XTick at 0x15de70854c0>,
#  <matplotlib.axis.XTick at 0x15de6fd25a0>,
#  <matplotlib.axis.XTick at 0x15de7084a70>,
#  <matplotlib.axis.XTick at 0x15de7085f70>,
#  <matplotlib.axis.XTick at 0x15de7086690>,
#  <matplotlib.axis.XTick at 0x15de7086f00>,
#  <matplotlib.axis.XTick at 0x15de7087680>,
#  <matplotlib.axis.XTick at 0x15de7086ed0>,
#  <matplotlib.axis.XTick at 0x15de7085a90>,
#  <matplotlib.axis.XTick at 0x15de70871d0>,
#  <matplotlib.axis.XTick at 0x15de70a4830>,
#  <matplotlib.axis.XTick at 0x15de70a4f50>,
#  <matplotlib.axis.XTick at 0x15de70852e0>,
#  <matplotlib.axis.XTick at 0x15de70a5220>,
#  <matplotlib.axis.XTick at 0x15de70a59d0>,
#  <matplotlib.axis.XTick at 0x15de70a6000>,
#  <matplotlib.axis.XTick at 0x15de70a6840>,
#  <matplotlib.axis.XTick at 0x15de70a6ff0>,
#  <matplotlib.axis.XTick at 0x15de70a6b40>,
#  <matplotlib.axis.XTick at 0x15de70a5880>,
#  <matplotlib.axis.XTick at 0x15de70a7c20>,
#  <matplotlib.axis.XTick at 0x15de70d03b0>,
#  <matplotlib.axis.XTick at 0x15de70a6930>,
#  <matplotlib.axis.XTick at 0x15de70d1100>,
#  <matplotlib.axis.XTick at 0x15de70a7800>,
#  <matplotlib.axis.XTick at 0x15de70d02c0>,
#  <matplotlib.axis.XTick at 0x15de70d1bb0>,
#  <matplotlib.axis.XTick at 0x15de70d2330>,
#  <matplotlib.axis.XTick at 0x15de70d2a20>,
#  <matplotlib.axis.XTick at 0x15de70864b0>,
#  <matplotlib.axis.XTick at 0x15de70d2060>,
#  <matplotlib.axis.XTick at 0x15de70d3440>,
#  <matplotlib.axis.XTick at 0x15de70d3bc0>,
#  <matplotlib.axis.XTick at 0x15de70f04a0>,
#  <matplotlib.axis.XTick at 0x15de70f0b60>,
#  <matplotlib.axis.XTick at 0x15de70d37a0>,
#  <matplotlib.axis.XTick at 0x15de70f0920>,
#  <matplotlib.axis.XTick at 0x15de70d37d0>,
#  <matplotlib.axis.XTick at 0x15de70f1ca0>,
#  <matplotlib.axis.XTick at 0x15de70f1790>,
#  <matplotlib.axis.XTick at 0x15de70f2d50>,
#  <matplotlib.axis.XTick at 0x15de70f29f0>,
#  <matplotlib.axis.XTick at 0x15de70f12e0>,
#  <matplotlib.axis.XTick at 0x15de70f3560>,
#  <matplotlib.axis.XTick at 0x15de70f3ce0>,
#  <matplotlib.axis.XTick at 0x15de7118650>,
#  <matplotlib.axis.XTick at 0x15de70f3d70>,
#  <matplotlib.axis.XTick at 0x15de70f2c60>,
#  <matplotlib.axis.XTick at 0x15de70f3b00>,
#  <matplotlib.axis.XTick at 0x15de6ff83b0>,
#  <matplotlib.axis.XTick at 0x15de7119310>,
#  <matplotlib.axis.XTick at 0x15de7119940>,
#  <matplotlib.axis.XTick at 0x15de705fd10>,
#  <matplotlib.axis.XTick at 0x15de7119760>,
#  <matplotlib.axis.XTick at 0x15de70f2480>,
#  <matplotlib.axis.XTick at 0x15de711ab10>,
#  <matplotlib.axis.XTick at 0x15de711b410>,
#  <matplotlib.axis.XTick at 0x15de711bb00>,
#  <matplotlib.axis.XTick at 0x15de711ba70>,
#  <matplotlib.axis.XTick at 0x15de711a030>,
#  <matplotlib.axis.XTick at 0x15de7138590>,
#  <matplotlib.axis.XTick at 0x15de7138d10>,
#  <matplotlib.axis.XTick at 0x15de7139400>,
#  <matplotlib.axis.XTick at 0x15de7139c40>,
#  <matplotlib.axis.XTick at 0x15de7139ac0>,
#  <matplotlib.axis.XTick at 0x15de71383e0>,
#  <matplotlib.axis.XTick at 0x15de713a3c0>,
#  <matplotlib.axis.XTick at 0x15de713ab40>,
#  <matplotlib.axis.XTick at 0x15de713b2c0>,
#  <matplotlib.axis.XTick at 0x15de70f1400>,
#  <matplotlib.axis.XTick at 0x15de713a960>,
#  <matplotlib.axis.XTick at 0x15de713bc20>,
#  <matplotlib.axis.XTick at 0x15de7160530>,
#  <matplotlib.axis.XTick at 0x15de7160cb0>,
#  <matplotlib.axis.XTick at 0x15de71613a0>,
#  <matplotlib.axis.XTick at 0x15de71389e0>,
#  <matplotlib.axis.XTick at 0x15de7160740>,
#  <matplotlib.axis.XTick at 0x15de713a000>,
#  <matplotlib.axis.XTick at 0x15de7162540>,
#  <matplotlib.axis.XTick at 0x15de7162db0>,
#  <matplotlib.axis.XTick at 0x15de7163530>,
#  <matplotlib.axis.XTick at 0x15de7162b10>,
#  <matplotlib.axis.XTick at 0x15de7160bf0>,
#  <matplotlib.axis.XTick at 0x15de7163ef0>,
#  <matplotlib.axis.XTick at 0x15de7184770>,
#  <matplotlib.axis.XTick at 0x15de7184da0>,
#  <matplotlib.axis.XTick at 0x15de7163560>,
#  <matplotlib.axis.XTick at 0x15de7185100>,
#  <matplotlib.axis.XTick at 0x15de7185970>,
#  <matplotlib.axis.XTick at 0x15de7185fa0>,
#  <matplotlib.axis.XTick at 0x15de7186870>,
#  <matplotlib.axis.XTick at 0x15de7186f60>,
#  <matplotlib.axis.XTick at 0x15de7186db0>,
#  <matplotlib.axis.XTick at 0x15de7185cd0>,
#  <matplotlib.axis.XTick at 0x15de7187950>,
#  <matplotlib.axis.XTick at 0x15de7187f80>,
#  <matplotlib.axis.XTick at 0x15de7187a10>,
#  <matplotlib.axis.XTick at 0x15de71a0f50>,
#  <matplotlib.axis.XTick at 0x15de7187590>,
#  <matplotlib.axis.XTick at 0x15de71a0500>,
#  <matplotlib.axis.XTick at 0x15de71a1a30>,
#  <matplotlib.axis.XTick at 0x15de71a2060>,
#  <matplotlib.axis.XTick at 0x15de71a27e0>,
#  <matplotlib.axis.XTick at 0x15de71866f0>,
#  <matplotlib.axis.XTick at 0x15de71a1e50>,
#  <matplotlib.axis.XTick at 0x15de71a3350>,
#  <matplotlib.axis.XTick at 0x15de71a3a40>,
#  <matplotlib.axis.XTick at 0x15de71cc380>,
#  <matplotlib.axis.XTick at 0x15de71cca70>,
#  <matplotlib.axis.XTick at 0x15de71a3950>,
#  <matplotlib.axis.XTick at 0x15de71cc740>,
#  <matplotlib.axis.XTick at 0x15de71cd4f0>,
#  <matplotlib.axis.XTick at 0x15de71cdaf0>,
#  <matplotlib.axis.XTick at 0x15de71ce300>,
#  <matplotlib.axis.XTick at 0x15de71cea80>,
#  <matplotlib.axis.XTick at 0x15de7187500>,
#  <matplotlib.axis.XTick at 0x15de711bec0>,
#  <matplotlib.axis.XTick at 0x15de71cd910>,
#  <matplotlib.axis.XTick at 0x15de71cef30>,
#  <matplotlib.axis.XTick at 0x15de71cf680>,
#  <matplotlib.axis.XTick at 0x15de71cfdd0>,
#  <matplotlib.axis.XTick at 0x15de71cee40>,
#  <matplotlib.axis.XTick at 0x15de7163f20>,
#  <matplotlib.axis.XTick at 0x15de71f4770>,
#  <matplotlib.axis.XTick at 0x15de71f4e30>,
#  <matplotlib.axis.XTick at 0x15de71f5520>,
#  <matplotlib.axis.XTick at 0x15de70d01a0>,
#  <matplotlib.axis.XTick at 0x15de71f55b0>,
#  <matplotlib.axis.XTick at 0x15de71f5f70>,
#  <matplotlib.axis.XTick at 0x15de71f6660>,
#  <matplotlib.axis.XTick at 0x15de71f6e10>,
#  <matplotlib.axis.XTick at 0x15de71f7590>,
#  <matplotlib.axis.XTick at 0x15de71f7500>,
#  <matplotlib.axis.XTick at 0x15de71f49e0>,
#  <matplotlib.axis.XTick at 0x15de71f7f20>,
#  <matplotlib.axis.XTick at 0x15de721c950>,
#  <matplotlib.axis.XTick at 0x15de721d010>,
#  <matplotlib.axis.XTick at 0x15de721d790>,
#  <matplotlib.axis.XTick at 0x15de71f7290>,
#  <matplotlib.axis.XTick at 0x15de721c5c0>,
#  <matplotlib.axis.XTick at 0x15de721e090>,
#  <matplotlib.axis.XTick at 0x15de721e900>,
#  <matplotlib.axis.XTick at 0x15de721f0b0>,
#  <matplotlib.axis.XTick at 0x15de71f6930>,
#  <matplotlib.axis.XTick at 0x15de721e510>,
#  <matplotlib.axis.XTick at 0x15de721f9e0>,
#  <matplotlib.axis.XTick at 0x15de72342f0>,
#  <matplotlib.axis.XTick at 0x15de7234a70>,
#  <matplotlib.axis.XTick at 0x15de72350a0>,
#  <matplotlib.axis.XTick at 0x15de721f9b0>,
#  <matplotlib.axis.XTick at 0x15de7234950>,
#  <matplotlib.axis.XTick at 0x15de7235b20>,
#  <matplotlib.axis.XTick at 0x15de7236210>,
#  <matplotlib.axis.XTick at 0x15de72369c0>,
#  <matplotlib.axis.XTick at 0x15de7237080>,
#  <matplotlib.axis.XTick at 0x15de72368d0>,
#  <matplotlib.axis.XTick at 0x15de7234d70>,
#  <matplotlib.axis.XTick at 0x15de7237b30>,
#  <matplotlib.axis.XTick at 0x15de725c380>,
#  <matplotlib.axis.XTick at 0x15de725cad0>,
#  <matplotlib.axis.XTick at 0x15de7237f50>,
#  <matplotlib.axis.XTick at 0x15de7234260>,
#  <matplotlib.axis.XTick at 0x15de725d490>,
#  <matplotlib.axis.XTick at 0x15de725d430>,
#  <matplotlib.axis.XTick at 0x15de725e270>,
#  <matplotlib.axis.XTick at 0x15de725ea20>,
#  <matplotlib.axis.XTick at 0x15de725e330>,
#  <matplotlib.axis.XTick at 0x15de725d7c0>,
#  <matplotlib.axis.XTick at 0x15de725f3e0>,
#  <matplotlib.axis.XTick at 0x15de725f530>,
#  <matplotlib.axis.XTick at 0x15de725f590>,
#  <matplotlib.axis.XTick at 0x15de727cc50>,
#  <matplotlib.axis.XTick at 0x15de725f1d0>,
#  <matplotlib.axis.XTick at 0x15de727c290>,
#  <matplotlib.axis.XTick at 0x15de727d5b0>,
#  <matplotlib.axis.XTick at 0x15de727dc40>,
#  <matplotlib.axis.XTick at 0x15de727e450>,
#  <matplotlib.axis.XTick at 0x15de725dfd0>,
#  <matplotlib.axis.XTick at 0x15de727da90>,
#  <matplotlib.axis.XTick at 0x15de727ee70>,
#  <matplotlib.axis.XTick at 0x15de727f530>,
#  <matplotlib.axis.XTick at 0x15de727fbc0>,
#  <matplotlib.axis.XTick at 0x15de72a0470>,
#  <matplotlib.axis.XTick at 0x15de727f9b0>,
#  <matplotlib.axis.XTick at 0x15de727e240>,
#  <matplotlib.axis.XTick at 0x15de721f7a0>,
#  <matplotlib.axis.XTick at 0x15de727ea50>,
#  <matplotlib.axis.XTick at 0x15de72a1160>,
#  <matplotlib.axis.XTick at 0x15de72a1910>,
#  <matplotlib.axis.XTick at 0x15de725cec0>,
#  <matplotlib.axis.XTick at 0x15de72a0e30>,
#  <matplotlib.axis.XTick at 0x15de72a22d0>,
#  <matplotlib.axis.XTick at 0x15de72a2900>,
#  <matplotlib.axis.XTick at 0x15de72a3140>,
#  <matplotlib.axis.XTick at 0x15de72a38f0>]

# %%
plt.plot(df['Date'], df['Shape of You'], label = 'Shape of You')
plt.plot(df['Date'], df['Despacito'], label = 'Despacito')
plt.legend()
plt.xlabel('Dates')
plt.ylabel('Streams')
# Out:
# Text(0, 0.5, 'Streams')
